# %%
 # import the  libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the file data
df=pd.read_csv("Automobile_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Read the file data
# ----> 2 df=pd.read_csv("Automobile_data.csv")
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# to display first 5 records
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  width  height engine-type  \
# 0  convertible          rwd           front   64.1    48.8        dohc
# 1  convertible          rwd           front   64.1    48.8        dohc
# 2    hatchback          rwd           front   65.5    52.4        ohcv
# 3        sedan          fwd           front   66.2    54.3         ohc
# 4        sedan          4wd           front   66.4    54.3         ohc
#
#    engine-size horsepower  city-mpg  highway-mpg  price
# ...

# %%
# to find the shape of data
df.shape
# Out:
# (205, 17)

# %%
# missing values
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# duplicate data
df.duplicated().sum()
# Out:
# 0

# %%
# information of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   width              205 non-null    float64
#  10  height             205 non-null    float64
#  11  engine-type        205 non-null    object
#  12  engine-size        205 non-null    int64
#  13  horsepower         205 non-null    object
#  14  city-mpg           205 non-null    int64
#  15  highway-mpg        205 non-null    int64
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  width  height engine-type  \
# 0  convertible          rwd           front   64.1    48.8        dohc
# 1  convertible          rwd           front   64.1    48.8        dohc
# 2    hatchback          rwd           front   65.5    52.4        ohcv
# 3        sedan          fwd           front   66.2    54.3         ohc
# 4        sedan          4wd           front   66.4    54.3         ohc
#
#    engine-size horsepower  city-mpg  highway-mpg  price
# ...

# %%
df['normalized-losses'].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
df['normalized-losses']=df['normalized-losses'].replace('?',np.NAN)

# %%
df['horsepower'].unique()
# Out:
# array(['111', '154', '102', '115', '110', '140', '160', '101', '121',
#        '182', '48', '70', '68', '88', '145', '58', '76', '60', '86',
#        '100', '78', '90', '176', '262', '135', '84', '64', '120', '72',
#        '123', '155', '184', '175', '116', '69', '55', '97', '152', '200',
#        '95', '142', '143', '207', '288', '?', '73', '82', '94', '62',
#        '56', '112', '92', '161', '156', '52', '85', '114', '162', '134',
#        '106'], dtype=object)

# %%
df['horsepower']=df['horsepower'].replace('?',np.nan)

# %%
df['price'].unique()
# Out:
# array(['13495', '16500', '13950', '17450', '15250', '17710', '18920',
#        '23875', '?', '16430', '16925', '20970', '21105', '24565', '30760',
#        '41315', '36880', '5151', '6295', '6575', '5572', '6377', '7957',
#        '6229', '6692', '7609', '8558', '8921', '12964', '6479', '6855',
#        '5399', '6529', '7129', '7295', '7895', '9095', '8845', '10295',
#        '12945', '10345', '6785', '11048', '32250', '35550', '36000',
#        '5195', '6095', '6795', '6695', '7395', '10945', '11845', '13645',
#        '15645', '8495', '10595', '10245', '10795', '11245', '18280',
#        '18344', '25552', '28248', '28176', '31600', '34184', '35056',
#        '40960', '45400', '16503', '5389', '6189', '6669', '7689', '9959',
#        '8499', '12629', '14869', '14489', '6989', '8189', '9279', '5499',
#        '7099', '6649', '6849', '7349', '7299', '7799', '7499', '7999',
#        '8249', '8949', '9549', '13499', '14399', '17199', '19699',
# ...

# %%
df['price']=df['price'].replace('?',np.nan)

# %%
df['price']=df['price'].astype('float')

# %%
df['horsepower']=df['horsepower'].astype('float')

# %%
df['normalized-losses']=df['normalized-losses'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   width              205 non-null    float64
#  10  height             205 non-null    float64
#  11  engine-type        205 non-null    object
#  12  engine-size        205 non-null    int64
#  13  horsepower         203 non-null    float64
#  14  city-mpg           205 non-null    int64
#  15  highway-mpg        205 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
mean_NL=df['normalized-losses'].mean()
mean_NL
# Out:
# 122.0

# %%
df['normalized-losses'].fillna(mean_NL,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'width', 'height', 'engine-type', 'engine-size', 'horsepower',
#        'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
num_col =df.select_dtypes(['int64','float64'])
cat_col=df.select_dtypes('object')

# %%
import seaborn as sns

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df,y='price')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df,x='price',y='make')
plt.show()

# %%
df[(df['price']>15000) & (df['make']=='toyota')].index
# Out:
# Index([172, 178, 179, 180, 181], dtype='int64')

# %%
df.drop(index=[172, 178, 179, 180, 181],inplace=True)

# %%
df[(df['price']<25000) & (df['make']=='porsche')].index
# Out:
# Index([125], dtype='int64')

# %%
df.drop(index=[125],inplace=True)

# %%
df[(df['price']>11000) & (df['make']=='plymouth')].index
# Out:
# Index([124], dtype='int64')

# %%
df.drop(index=[124],inplace=True)

# %%
df[(df['price']>13000) & (df['make']=='mitsubishi')].index
# Out:
# Index([83, 84], dtype='int64')

# %%
df.drop(index=[83,84],inplace=True)

# %%
df[(df['price']>12000) & (df['make']=='honda')].index
# Out:
# Index([41], dtype='int64')

# %%
df[(df['price']>12000) & (df['make']=='dodge')].index
# Out:
# Index([29], dtype='int64')

# %%
df.drop(index=[41,29],inplace=True)

# %%
df[(df['price']>20000) & (df['make']=='audi')].index
# Out:
# Index([8], dtype='int64')

# %%
df.drop(index=[8],inplace=True)

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df,x='price',y='make')
plt.show()

# %%
num_col.head()
# Out:
#    symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0          3              122.0   64.1    48.8          130       111.0
# 1          3              122.0   64.1    48.8          130       111.0
# 2          1              122.0   65.5    52.4          152       154.0
# 3          2              164.0   66.2    54.3          109       102.0
# 4          2              164.0   66.4    54.3          136       115.0
#
#    city-mpg  highway-mpg    price
# 0        21           27  13495.0
# 1        21           27  16500.0
# 2        19           26  16500.0
# 3        24           30  13950.0
# 4        18           22  17450.0

# %%
cat_col.head()
# Out:
#           make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
#
#   engine-location engine-type
# 0           front        dohc
# 1           front        dohc
# 2           front        ohcv
# 3           front         ohc
# 4           front         ohc

# %%
sns.countplot(df['make'])
plt.show()

# %%
for col in cat_col:
    
    sns.countplot(df[col])
    plt.show()

# %%
for col in num_col:
    sns.distplot(df[col])
    plt.show()

# %%
df['price'].skew()
# Out:
# 1.8454549346176783

# %%
np.sqrt(df['price']).skew()
# Out:
# 1.2923638767721326

# %%
np.log(df['price']).skew()
# Out:
# 0.7703505775690691

# %%
for col in num_col:
    print(col,":",df[col].skew())
# Out:
# symboling : 0.21814534789084933
# normalized-losses : 0.8760879518091573
# width : 0.918470487449649
# height : -0.009502202278012075
# engine-size : 2.111048622376327
# horsepower : 1.355005335047949
# city-mpg : 0.5892544098777251
# highway-mpg : 0.4730656344891973
# price : 1.8454549346176783

# %%
for col in num_col:
    if df[col].skew()>0.5:
        df[col]=np.log(df[col])
        print(col,":",df[col].skew())
    else:
        print(col,":",df[col].skew())
# Out:
# symboling : 0.21814534789084933
# normalized-losses : 0.038580714874414855
# width : 0.8314081231083168
# height : -0.009502202278012075
# engine-size : 1.0169883991920905
# horsepower : 0.5325097473952981
# city-mpg : -0.11958025191839514
# highway-mpg : 0.4730656344891973
# price : 0.7703505775690691

# %%
for col in num_col:
    if df[col].skew()>0.5:
        df[col]=np.sqrt(df[col])
        print(col,":",df[col].skew())
    else:
        print(col,":",df[col].skew())
# Out:
# symboling : 0.21814534789084933
# normalized-losses : 0.038580714874414855
# width : 0.8209633334015178
# height : -0.009502202278012075
# engine-size : 0.9174388946824125
# horsepower : 0.4526429926715822
# city-mpg : -0.11958025191839514
# highway-mpg : 0.4730656344891973
# price : 0.718748474002456

# %%
for col in num_col:
    sns.distplot(df[col])
    plt.show()

# %%
cat_col.columns
# Out:
# Index(['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style',
#        'drive-wheels', 'engine-location', 'engine-type'],
#       dtype='object')

# %%
num_col.head()
# Out:
#    symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0          3              122.0   64.1    48.8          130       111.0
# 1          3              122.0   64.1    48.8          130       111.0
# 2          1              122.0   65.5    52.4          152       154.0
# 3          2              164.0   66.2    54.3          109       102.0
# 4          2              164.0   66.4    54.3          136       115.0
#
#    city-mpg  highway-mpg    price
# 0        21           27  13495.0
# 1        21           27  16500.0
# 2        19           26  16500.0
# 3        24           30  13950.0
# 4        18           22  17450.0

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
ss=StandardScaler()
scaler=MinMaxScaler()

# %%
num_col['engine-size'].head()
# Out:
# 0    130
# 1    130
# 2    152
# 3    109
# 4    136
# Name: engine-size, dtype: int64

# %%
new_scaled_data=scaler.fit_transform(num_col[['engine-size']])

# %%
print("min::",new_scaled_data.min())
print("max::",new_scaled_data.max())
# Out:
# min:: 0.0
# max:: 1.0

# %%
scaled_data=ss.fit_transform(num_col[['engine-size']])

# %%
print("mean::",round(scaled_data.mean()))
print("std::",scaled_data.std())
# Out:
# mean:: 0
# std:: 1.0

# %%
for col in num_col:
    ss=StandardScaler()
    num_col[col]=ss.fit_transform(num_col[[col]])

# %%
num_col
# Out:
#      symboling  normalized-losses     width    height  engine-size  \
# 0     1.723340           0.000000 -0.846476 -2.038557     0.076255
# 1     1.723340           0.000000 -0.846476 -2.038557     0.076255
# 2     0.128249           0.000000 -0.181609 -0.563681     0.604493
# 3     0.925794           1.309368  0.150824  0.214726    -0.427972
# 4     0.925794           1.309368  0.245805  0.214726     0.220320
# ..         ...                ...       ...       ...          ...
# 200  -1.466843          -0.841737  1.433067  0.706351     0.340374
# 201  -1.466843          -0.841737  1.385576  0.706351     0.340374
# 202  -1.466843          -0.841737  1.433067  0.706351     1.108721
# 203  -1.466843          -0.841737  1.433067  0.706351     0.436418
# 204  -1.466843          -0.841737  1.433067  0.706351     0.340374
#
#      horsepower  city-mpg  highway-mpg     price
# 0      0.202967 -0.652776    -0.539128  0.031609
# 1      0.202967 -0.652776    -0.539128  0.409187
# ...

# %%
pip install pandas-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: C:\Users\admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from pandas_profiling import profile_report
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15804\1782445000.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import profile_report
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pandas_profiling import profile_report
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas_profiling\profile_report.py:13
#      10 from tqdm.auto import tqdm
#      11 from visions import VisionsTypeset
# ---> 13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
#      15 from pandas_profiling.model.alerts import AlertType
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas_profiling\config.py:5
# ...

# %%
df=pd.read_csv('D:\itvedant\Automobile_data (1).csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15804\3092157278.py:1: SyntaxWarning: invalid escape sequence '\i'
#   df=pd.read_csv('D:\itvedant\Automobile_data (1).csv')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  width  height engine-type  \
# 0  convertible          rwd           front   64.1    48.8        dohc
# 1  convertible          rwd           front   64.1    48.8        dohc
# 2    hatchback          rwd           front   65.5    52.4        ohcv
# 3        sedan          fwd           front   66.2    54.3         ohc
# 4        sedan          4wd           front   66.4    54.3         ohc
#
#    engine-size horsepower  city-mpg  highway-mpg  price
# ...

# %%
num_col =df.select_dtypes(['int64','float64'])
cat_col=df.select_dtypes('object')

# %%
cat_col.columns
# Out:
# Index([], dtype='object')

# %%
df=df.dropna('nomalized-losses','engine-location')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df=df.dropna('nomalized-losses','engine-location')
#
# TypeError: DataFrame.dropna() takes 1 positional argument but 3 were given

# %%
from sklearn.preprocessing import  LabelEncoder

# %%
for col in cat_col:
    le=LabelEncoder()
    df[col]=le.fit_transform(df[[col]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=((20,10)))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
x_test.shape
# Out:
# (41, 16)

# %%
x_train.shape
# Out:
# (164, 16)

# %%
y_test.shape
# Out:
# (41,)

# %%
y_train.shape
# Out:
# (164,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 63.90412827,  86.93517433, 120.79908766,  77.66883826,
#         31.84143355, 121.77198293, 123.83548079, 123.47357402,
#        125.18097404, 122.52863242,  79.10363083, 102.72319555,
#         70.22112195, 107.17089388,  60.136478  , 118.60296139,
#        159.52031765,  99.10514281, 120.60602038, 120.73188313,
#        100.61345537,  81.90934321, 108.21541751, 170.30116709,
#        126.19227414,  76.10823378,  83.53232982,  82.0457209 ,
#        136.12754031,  78.17820174,  27.79031462, 125.9106564 ,
#        123.9013275 ,  64.37251219, 105.71104475,  17.31396218,
#        118.62032323,  33.64277792, 138.38203421,  99.10514281,
#        124.31894884])

# %%
model.score(x_test,y_test)
# Out:
# 0.12268631000644414

# %%
model.score(x_train,y_train)
# Out:
# 0.28033032656305357
